# %% [markdown]
# <a href="https://colab.research.google.com/github/sumit1136/cartoonify-1/blob/main/sumit1136/cartoonify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab import files
originalImage = files.upload()
# Out:
#      <input type="file" id="files-736f1f07-adc6-4e4c-87a9-6c565dad1ec1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-736f1f07-adc6-4e4c-87a9-6c565dad1ec1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving vishy.jpeg to vishy (1).jpeg

# %%
from skimage import io
from google.colab.patches import cv2_imshow

# %%
for img in originalImage:
  io.imshow(img)

# %%
img=cv2.imread(img)
io.imshow(img)

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
io.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
io.imshow(gray)

# %%
imgBlur= cv2.medianBlur(gray, 5)
io.imshow(imgBlur)

# %%
imgEdge=cv2.adaptiveThreshold(imgBlur,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 9, 9)
io.imshow(imgEdge)

# %%
colored=cv2.bilateralFilter(img,9,250,250)
cartoon=cv2.bitwise_and(colored,colored,mask=imgEdge)
io.imshow(cartoon)
